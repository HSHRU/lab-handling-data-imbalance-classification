# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.utils import resample
from sklearn.metrics import confusion_matrix

# %%
ChurnData = pd.read_csv('.\\files_for_lab\\Customer-Churn.csv')
ChurnData.head(40)
# Out:
#     gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   Female              0     Yes         No       1           No
# 1     Male              0      No         No      34          Yes
# 2     Male              0      No         No       2          Yes
# 3     Male              0      No         No      45           No
# 4   Female              0      No         No       2          Yes
# 5   Female              0      No         No       8          Yes
# 6     Male              0      No        Yes      22          Yes
# 7   Female              0      No         No      10           No
# 8   Female              0     Yes         No      28          Yes
# 9     Male              0      No        Yes      62          Yes
# 10    Male              0     Yes        Yes      13          Yes
# 11    Male              0      No         No      16          Yes
# 12    Male              0     Yes         No      58          Yes
# 13    Male              0      No         No      49          Yes
# 14    Male              0      No         No      25          Yes
# 15  Female              0     Yes        Yes      69          Yes
# 16  Female              0      No         No      52          Yes
# 17    Male              0      No        Yes      71          Yes
# 18  Female              0     Yes        Yes      10          Yes
# 19  Female              0      No         No      21          Yes
# 20    Male              1      No         No       1           No
# 21    Male              0     Yes         No      12          Yes
# 22    Male              0      No         No       1          Yes
# 23  Female              0     Yes         No      58          Yes
# 24    Male              0     Yes        Yes      49          Yes
# 25  Female              0      No         No      30          Yes
# 26    Male              0     Yes        Yes      47          Yes
# 27    Male              0     Yes        Yes       1           No
# 28    Male              0     Yes         No      72          Yes
# 29  Female              0      No        Yes      17          Yes
# 30  Female              1     Yes         No      71          Yes
# 31    Male              1     Yes         No       2          Yes
# 32  Female              0     Yes        Yes      27          Yes
# 33    Male              0      No         No       1          Yes
# 34    Male              1      No         No       1          Yes
# 35  Female              0     Yes        Yes      72          Yes
# 36    Male              0      No         No       5          Yes
# 37  Female              0      No         No      46          Yes
# 38    Male              0      No         No      34          Yes
# 39  Female              0      No         No      11          Yes
#
#          OnlineSecurity         OnlineBackup     DeviceProtection  \
# 0                    No                  Yes                   No
# 1                   Yes                   No                  Yes
# 2                   Yes                  Yes                   No
# 3                   Yes                   No                  Yes
# 4                    No                   No                   No
# 5                    No                   No                  Yes
# 6                    No                  Yes                   No
# 7                   Yes                   No                   No
# 8                    No                   No                  Yes
# 9                   Yes                  Yes                   No
# 10                  Yes                   No                   No
# 11  No internet service  No internet service  No internet service
# 12                   No                   No                  Yes
# 13                   No                  Yes                  Yes
# 14                  Yes                   No                  Yes
# 15                  Yes                  Yes                  Yes
# 16  No internet service  No internet service  No internet service
# 17                  Yes                   No                  Yes
# 18                   No                   No                  Yes
# 19                   No                  Yes                  Yes
# 20                   No                   No                  Yes
# 21  No internet service  No internet service  No internet service
# 22  No internet service  No internet service  No internet service
# 23                   No                  Yes                   No
# 24                  Yes                  Yes                   No
# 25                  Yes                  Yes                   No
# 26                   No                  Yes                   No
# 27                   No                  Yes                   No
# 28                  Yes                  Yes                  Yes
# 29                   No                   No                   No
# 30                  Yes                  Yes                  Yes
# 31                   No                   No                  Yes
# 32                  Yes                  Yes                  Yes
# 33  No internet service  No internet service  No internet service
# 34                   No                   No                   No
# 35                  Yes                  Yes                   No
# 36                   No                   No                   No
# 37                   No                   No                  Yes
# 38                   No                  Yes                  Yes
# 39                   No                   No                  Yes
#
#             TechSupport          StreamingTV      StreamingMovies  \
# 0                    No                   No                   No
# 1                    No                   No                   No
# 2                    No                   No                   No
# 3                   Yes                   No                   No
# 4                    No                   No                   No
# 5                    No                  Yes                  Yes
# 6                    No                  Yes                   No
# 7                    No                   No                   No
# 8                   Yes                  Yes                  Yes
# 9                    No                   No                   No
# 10                   No                   No                   No
# 11  No internet service  No internet service  No internet service
# 12                   No                  Yes                  Yes
# 13                   No                  Yes                  Yes
# 14                  Yes                  Yes                  Yes
# 15                  Yes                  Yes                  Yes
# 16  No internet service  No internet service  No internet service
# 17                   No                  Yes                  Yes
# 18                  Yes                   No                   No
# 19                   No                   No                  Yes
# 20                   No                   No                  Yes
# 21  No internet service  No internet service  No internet service
# 22  No internet service  No internet service  No internet service
# 23                  Yes                   No                   No
# 24                  Yes                   No                   No
# 25                   No                   No                   No
# 26                   No                  Yes                  Yes
# 27                   No                   No                   No
# 28                  Yes                  Yes                  Yes
# 29                   No                  Yes                  Yes
# 30                  Yes                   No                   No
# 31                   No                  Yes                  Yes
# 32                  Yes                   No                   No
# 33  No internet service  No internet service  No internet service
# 34                   No                   No                   No
# 35                  Yes                  Yes                   No
# 36                   No                   No                   No
# 37                   No                   No                   No
# 38                   No                  Yes                  Yes
# 39                   No                  Yes                  Yes
#
#           Contract  MonthlyCharges TotalCharges Churn
# 0   Month-to-month           29.85        29.85    No
# 1         One year           56.95       1889.5    No
# 2   Month-to-month           53.85       108.15   Yes
# 3         One year           42.30      1840.75    No
# 4   Month-to-month           70.70       151.65   Yes
# 5   Month-to-month           99.65        820.5   Yes
# 6   Month-to-month           89.10       1949.4    No
# 7   Month-to-month           29.75        301.9    No
# 8   Month-to-month          104.80      3046.05   Yes
# 9         One year           56.15      3487.95    No
# 10  Month-to-month           49.95       587.45    No
# 11        Two year           18.95        326.8    No
# 12        One year          100.35       5681.1    No
# 13  Month-to-month          103.70       5036.3   Yes
# 14  Month-to-month          105.50      2686.05    No
# 15        Two year          113.25      7895.15    No
# 16        One year           20.65      1022.95    No
# 17        Two year          106.70      7382.25    No
# 18  Month-to-month           55.20       528.35   Yes
# 19  Month-to-month           90.05       1862.9    No
# 20  Month-to-month           39.65        39.65   Yes
# 21        One year           19.80       202.25    No
# 22  Month-to-month           20.15        20.15   Yes
# 23        Two year           59.90       3505.1    No
# 24  Month-to-month           59.60       2970.3    No
# 25  Month-to-month           55.30       1530.6    No
# 26  Month-to-month           99.35      4749.15   Yes
# 27  Month-to-month           30.20         30.2   Yes
# 28        Two year           90.25      6369.45    No
# 29  Month-to-month           64.70       1093.1   Yes
# 30        Two year           96.35      6766.95    No
# 31  Month-to-month           95.50       181.65    No
# 32        One year           66.15      1874.45    No
# 33  Month-to-month           20.20         20.2    No
# 34  Month-to-month           45.25        45.25    No
# 35        Two year           99.90       7251.7    No
# 36  Month-to-month           69.70        316.9   Yes
# 37  Month-to-month           74.80       3548.3    No
# 38  Month-to-month          106.35      3549.25   Yes
# 39  Month-to-month           97.85       1105.4   Yes

# %%
ChurnData.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
ChurnData.shape
# Out:
# (7043, 16)

# %%
ChurnData
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#      OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 0                No          Yes               No          No          No
# 1               Yes           No              Yes          No          No
# 2               Yes          Yes               No          No          No
# 3               Yes           No              Yes         Yes          No
# 4                No           No               No          No          No
# ...             ...          ...              ...         ...         ...
# 7038            Yes           No              Yes         Yes         Yes
# 7039             No          Yes              Yes          No         Yes
# 7040            Yes           No               No          No          No
# 7041             No           No               No          No          No
# 7042            Yes           No              Yes         Yes         Yes
#
#      StreamingMovies        Contract  MonthlyCharges TotalCharges Churn
# 0                 No  Month-to-month           29.85        29.85    No
# 1                 No        One year           56.95       1889.5    No
# 2                 No  Month-to-month           53.85       108.15   Yes
# 3                 No        One year           42.30      1840.75    No
# 4                 No  Month-to-month           70.70       151.65   Yes
# ...              ...             ...             ...          ...   ...
# 7038             Yes        One year           84.80       1990.5    No
# 7039             Yes        One year          103.20       7362.9    No
# 7040              No  Month-to-month           29.60       346.45    No
# 7041              No  Month-to-month           74.40        306.6   Yes
# 7042             Yes        Two year          105.65       6844.5    No
#
# [7043 rows x 16 columns]

# %%
ChurnData['TotalCharges']
# Out:
# 0         29.85
# 1        1889.5
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038     1990.5
# 7039     7362.9
# 7040     346.45
# 7041      306.6
# 7042     6844.5
# Name: TotalCharges, Length: 7043, dtype: object

# %%
ChurnData['TotalCharges']= ChurnData['TotalCharges'].str.replace(' ', '0')
#ChurnData['TotalCharges'].fillna(0, inplace = True)

# %%
ChurnData["TotalCharges"] = pd.to_numeric(ChurnData["TotalCharges"])

# %%
ChurnData['TotalCharges'] = pd.to_numeric(ChurnData['TotalCharges'], errors = 'coerce')

# %%
ChurnData.isna().sum()/len(ChurnData)*100
# Out:
# gender              0.0
# SeniorCitizen       0.0
# Partner             0.0
# Dependents          0.0
# tenure              0.0
# PhoneService        0.0
# OnlineSecurity      0.0
# OnlineBackup        0.0
# DeviceProtection    0.0
# TechSupport         0.0
# StreamingTV         0.0
# StreamingMovies     0.0
# Contract            0.0
# MonthlyCharges      0.0
# TotalCharges        0.0
# Churn               0.0
# dtype: float64

# %% [markdown]
# ###### Scale the features either by using normalizer or a standard scaler.

# %%
churn_num = ChurnData.select_dtypes(include = np.number)
churn_cat = ChurnData.select_dtypes(include = object)

# %%
scaler = MinMaxScaler()
numerical_scaled = scaler.fit_transform(churn_num)
numerical_scaled = pd.DataFrame(numerical_scaled, columns = churn_num.columns)
numerical_scaled
# Out:
#       SeniorCitizen    tenure  MonthlyCharges  TotalCharges
# 0               0.0  0.013889        0.115423      0.003437
# 1               0.0  0.472222        0.385075      0.217564
# 2               0.0  0.027778        0.354229      0.012453
# 3               0.0  0.625000        0.239303      0.211951
# 4               0.0  0.027778        0.521891      0.017462
# ...             ...       ...             ...           ...
# 7038            0.0  0.333333        0.662189      0.229194
# 7039            0.0  1.000000        0.845274      0.847792
# 7040            0.0  0.152778        0.112935      0.039892
# 7041            1.0  0.055556        0.558706      0.035303
# 7042            0.0  0.916667        0.869652      0.788101
#
# [7043 rows x 4 columns]

# %% [markdown]
# ###### Split the data into a training set and a test set.

# %%
X = numerical_scaled
y = ChurnData['Churn']
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %% [markdown]
# ###### Fit a logistic regression model on the training data.

# %%
LR = LogisticRegression(random_state=0, solver='lbfgs')
LR.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %% [markdown]
# ###### Check the accuracy on the test data.

# %%
print('accuracy:', LR.score(X_train, y_train))
og_accuracy= LR.score(X_train, y_train)
# Out:
# accuracy: 0.7926921620598258

# %%
y_pred = LR.predict(X_test)
confusion_matrix(y_test, y_pred)
# Out:
# array([[1180,  111],
#        [ 264,  206]], dtype=int64)

# %% [markdown]
# ###### Check for the imbalance.

# %%
ChurnData['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %% [markdown]
# ###### Use the resampling strategies used in class for upsampling and downsampling to create a balance between the two classes.

# %%
churn = pd.concat([X, y], axis = 1)
churn
# Out:
#       SeniorCitizen    tenure  MonthlyCharges  TotalCharges Churn
# 0               0.0  0.013889        0.115423      0.003437    No
# 1               0.0  0.472222        0.385075      0.217564    No
# 2               0.0  0.027778        0.354229      0.012453   Yes
# 3               0.0  0.625000        0.239303      0.211951    No
# 4               0.0  0.027778        0.521891      0.017462   Yes
# ...             ...       ...             ...           ...   ...
# 7038            0.0  0.333333        0.662189      0.229194    No
# 7039            0.0  1.000000        0.845274      0.847792    No
# 7040            0.0  0.152778        0.112935      0.039892    No
# 7041            1.0  0.055556        0.558706      0.035303   Yes
# 7042            0.0  0.916667        0.869652      0.788101    No
#
# [7043 rows x 5 columns]

# %%
category_0 = churn[churn['Churn'] == 'No']
category_1 = churn[churn['Churn'] == 'Yes']

# %%
category_0_undersampled = resample(category_0, 
                              replace=False, 
                              n_samples = len(category_1))

# %%
print(category_0_undersampled.shape)
print(category_1.shape)
# Out:
# (1869, 5)
# (1869, 5)

# %% [markdown]
# ###### Downsampling

# %%
data_downsampled = pd.concat([category_0_undersampled, category_1], axis=0)

# %%
data_downsampled['Churn'].value_counts()
# Out:
# No     1869
# Yes    1869
# Name: Churn, dtype: int64

# %%
X = data_downsampled.drop('Churn', axis = 1)
y = data_downsampled['Churn']
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
LR = LogisticRegression(random_state=0, solver='lbfgs')
LR.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
print('downsampled accuracy:', LR.score(X_train, y_train))
d_accuracy = LR.score(X_train, y_train)
# Out:
# downsampled accuracy: 0.7313592579379237

# %%
y_pred = LR.predict(X_test)
confusion_matrix(y_test, y_pred)
# Out:
# array([[354, 124],
#        [100, 357]], dtype=int64)

# %%
category_1_oversampled = resample(category_1, 
                                  replace=True, 
                                  n_samples = len(category_0))

# %%
print(category_0.shape)
print(category_1_oversampled.shape)
# Out:
# (5174, 5)
# (5174, 5)

# %% [markdown]
# ##### upsampling

# %%
data_upsampled = pd.concat([category_0, category_1_oversampled], axis=0)

# %%
data_upsampled['Churn'].value_counts()
# Out:
# No     5174
# Yes    5174
# Name: Churn, dtype: int64

# %%
X = data_upsampled.drop('Churn', axis = 1)
y = data_upsampled['Churn']
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
LR = LogisticRegression(random_state=0, solver='lbfgs')
LR.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
print('upsampled accuracy:', LR.score(X_train, y_train))
u_accuracy = LR.score(X_train, y_train)
# Out:
# upsampled accuracy: 0.7295451617059657

# %%
y_pred = LR.predict(X_test)
confusion_matrix(y_test, y_pred)
# Out:
# array([[944, 366],
#        [320, 957]], dtype=int64)

# %%
model = ['original', 'uppsampled', 'downsampled']
accuracy = [og_accuracy, u_accuracy, d_accuracy]
accuracy = pd.DataFrame([accuracy], columns = model).T
accuracy.columns = ['accuracy score']
accuracy
# Out:
#              accuracy score
# original           0.792692
# uppsampled         0.729545
# downsampled        0.731359
